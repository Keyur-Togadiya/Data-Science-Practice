# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
myurl = "https://www.flipkart.com/search?q=sennheiser&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_2_8_na_na_na&otracker1=AS_Query_OrganicAutoSuggest_2_8_na_na_na&as-pos=2&as-type=RECENT&suggestionId=sennheiser&requestId=c9c6fe71-62b0-43bf-bbc6-4e16bafb75ba&as-searchtext=sennhise&sort=price_desc"
getdata = uReq(myurl)
m = getdata.read()
getdata.close()

# %%
m
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch" />\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.14fc59.css" />\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta property="fb:page_id" content="102988293558"/>\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389"/>\n\t<meta name="robots" content="noodp" />\n\n\t<link rel=\'shortcut icon\' href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" />\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/>\n\n\t<meta property="og:type" content="website"/>\n\t<meta name="og_site_name" pr
# ...

# %%
html_parse1 = soup(m)
html_parse1
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.14fc59.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
contain = html_parse1.findAll("div", {'class': "_3liAhj"})
print(len(contain))
# Out:
# 40

# %%
with open("flipkart.csv","w") as f:

    headers = "Product, Price, Features \n"
    f.write(headers)
    
    for block in contain:
        product_s = block.findAll('a', {'class': '_2cLu-l'})
        product = product_s[0].text
        
        price_s = block.findAll('div', {'class': '_1vC4OE'})
        price = price_s[0].text
        price = price.replace(',','')
        price = price[1:]
        
        feature_s = block.findAll('div', {'class': '_1rcHFq'})
        feature = feature_s[0].text
        if "," in feature:
            ind = feature.index(',')
            feature = feature[:ind]

        f.write(product + ',' + price + ',' + feature  + "\n")

# %%
import pandas as pd
files = pd.read_csv('flipkart.csv', encoding="latin1")
files
# Out:
#                                               Product   Price  \
# 0         Sennheiser HD 820 Wired Headset without Mic  189990
# 1        Sennheiser HD 800s Wired Headset without Mic  139990
# 2     Sennheiser HD 800 Bluetooth Headset without Mic  109990
# 3         Sennheiser HD8 DJ Wired Headset without Mic   27990
# 4                Sennheiser PXC 550 Bluetooth Headset   27990
# 5   Sennheiser Momentum True Wireless Bluetooth He...   24990
# 6     Sennheiser Momentum M3 IETW 2 Bluetooth Headset   24990
# 7   Sennheiser Urbanite Xl Wireless Bluetooth Head...   24990
# 8     Sennheiser HD 599 Bluetooth Headset without Mic   20990
# 9       Sennheiser HD 6 Mix Wired Headset without Mic   19990
# 10               Sennheiser Ambeo Smart Wired Headset   19990
# 11   Sennheiser HDR 185 Bluetooth Headset without Mic   15990
# 12  Sennheiser  Urbanite XL Over-Ear Headphones Bl...   13834
# 13        Sennheiser HD 569 Wired Headset without Mic   12990
# ...

# %% [markdown]
# ### HTTP 403 forbidden request

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as soup

# %%
# Start 


my_url = "https://www.narendramodi.in/text-of-prime-minister-narendra-modi-s-special-key-note-address-at-us-ispf-us-india-summit-2020-551246"

req = Request(my_url, headers={'User-Agent': 'XYZ/3.0'})
webpage = urlopen(req, timeout=10).read()

print(webpage)
# Out:
# b'<!doctype html>\r\n<html>\r\n    <head>\r\n        <!-- Google Tag Manager -->\r\n        <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\r\n        new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\r\n        j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\r\n        \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\r\n        })(window,document,\'script\',\'dataLayer\',\'GTM-WRGDXV4\');</script>\r\n        <!-- End Google Tag Manager -->\r\n        \r\n        <title>\'Aatmanirbhar Bharat&rsquo; merges the local with the global: PM Modi</title>\r\n<meta name="description" content="Says India is becoming a leading attractions for Foreign Investment\r\nIndia received over 20 Billion Dollars of Foreign Investment this year: PM\r\nIndia offers affordability of geography, reliability an">\r\n<meta name="keywords" content="Bharat,the local,the global"/>\r\n<meta http-equiv="X-U
# ...

# %%
html_parser2 = soup(webpage)
contain = html_parser2.findAll("article", {'class':"articleBody main_article_content"})
contain
# Out:
# [<article class="articleBody main_article_content" data-id="551246">
#  <div class="twitterPoint" style="background: #aac0d1; width: auto; text-align: justify;">Says India is becoming a leading attractions for Foreign Investment</div>
#  <div class="twitterPoint" style="background: #aac0d1; width: auto;">India received over 20 Billion Dollars of Foreign Investment this year: PM</div>
#  <div class="twitterPoint" style="background: #aac0d1; width: auto;">India offers affordability of geography, reliability and political stability: PM</div>
#  <div class="twitterPoint" style="background: #aac0d1; width: auto;">India offers transparent and predictable tax regime; encourages &amp; supports honest tax payers: PM</div>
#  <div class="twitterPoint" style="background: #aac0d1; width: auto;">India being made one of the lowest tax destinations in the World with further incentive for new manufacturing units: PM</div>
# ...

# %%
with open("modi.csv","w") as f:
    artical = ""
    
    mk = contain[0].findAll('p')
    for m in range(len(mk)):
        try:
            arti = mk[m].text
            print(arti)
            f.write(arti + "\n")
        except:
            pass
# Out:
# Distinguished guests in India and USA,
# Namaste,
# It is wonderful to see US-ISPF bring together a diverse range of people for the US India Summit 2020. The work ofthe US-ISPF in bringing India and USA closer is commendable.
# I have known John Chambers for many years now. His affection towards India is very strong. A few years ago he was awarded the ‘Padma Shri’.
# Friends,
# The theme for this yearis a relevant one - Navigating New Challenges. When the year 2020 began, did anybody imagine this is how it would pan out? A global pandemic has impacted everyone. It is testing:our resilience, our public health systems, our economic systems.
# The current situation demands a fresh mind set.A mind set where the approach to development is human centric. Where there isa spirit of cooperationbetween everyone.
# Friends,
# ...
