# %% [markdown]
# ## Visualisation in Python - Matplotlib

# %% [markdown]
# ### Subplots: Comparing the trend of sales across different regions

# %% [markdown]
# -  Plotting different categories in the same graph or next to each other
# -  Helps in comparing and summarising the information over multiple categories

# %%
# importing numpy and the pyplot package of matplotlib
import numpy as np
import matplotlib.pyplot as plt

# Data for sales made by the company across three regions over the years 2012 to 2015
years = np.array(['2012', '2013', '2014', '2015'])
sales_Africa = np.array([127187.27, 144480.70, 229068.79, 283036.44])
sales_Asia_Pacific = np.array([713658.22, 863983.97, 1092231.65, 1372784.40])
sales_Europe = np.array([540750.63, 717611.40, 848670.24, 1180303.95])

# %%
# Plotting the trend of sales in African region over the 4 years
# Check the array names before plotting to avoid error
plt.plot(years,sales_Africa,c='red')
plt.show()

# %%
# Plotting the trend of sales in all three regions over the 4 years using subplots
f, al = plt.subplots(1,1,sharex=True)
africa, = al.plot(years,sales_Africa)
africa.set_label("Africa")
asia,= al.plot(years,sales_Asia_Pacific)
europe,= al.plot(years,sales_Europe)
asia.set_label("Asia Pacific")
europe.set_label("Europe")
europe.set_dashes([2,2,5,2])
plt.legend()
plt.show()

# %% [markdown]
# #### Subplots with a shared y-axis

# %%
# Plotting three charts with a shared y-axis
f,al = plt.subplots(1,3, sharey=True, sharex=True)
africa, = al[0].plot(years,sales_Africa)
africa.set_label("Africa")
asia,= al[1].plot(years,sales_Asia_Pacific, color='red')
europe,= al[2].plot(years,sales_Europe)
asia.set_label("Asia Pacific")
europe.set_label("Europe")
europe.set_dashes([2,2,5,2])
plt.legend([africa,asia,europe],("Africa","Asia","Europe"))

plt.show()

# %%
plt.bar(years,sales_Africa,color='red')
plt.bar(years,sales_Asia_Pacific,color='blue')
plt.bar(years,sales_Europe,color='green')
plt.show()

# %%
fig, ax = plt.subplots(1,1, sharex=True)

africa, = ax.bar(years, sales_Africa, color='blue')
europe, = ax.bar(years, sales_Asia_Pacific, color='green')
europe, = ax.bar(years, sales_Europe, color='red')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-aa7c8d140029> in <module>
#       1 fig, ax = plt.subplots(1,1, sharex=True)
#       2
# ----> 3 africa, = ax.bar(years, sales_Africa, color='blue')
#       4 europe, = ax.bar(years, sales_Asia_Pacific, color='green')
#       5 europe, = ax.bar(years, sales_Europe, color='red')
#
# ValueError: too many values to unpack (expected 1)
