# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\kutog\Downloads\Python

# %%
import pandas as pd

# %%
mydata = pd.read_csv("data.csv")

# %%
mydata
# Out:
#      area_id  variable_id  year     value symbol     md         area  \
# 0          4         4250  2012     4.990      I    [1]      Algeria
# 1          4         4252  2012     0.415      I    [2]      Algeria
# 2          4         4251  2012     3.020      I    [3]      Algeria
# 3          4         4253  2012     8.425      I    NaN      Algeria
# 4          4         4257  2012   225.000      K    NaN      Algeria
# ..       ...          ...   ...       ...    ...    ...          ...
# 894      156         4250  2010     3.207      E  [126]  New Zealand
# 895      156         4252  2010     1.184      E    NaN  New Zealand
# 896      156         4251  2010     0.810      E  [127]  New Zealand
# 897      156         4253  2010     5.201      E    NaN  New Zealand
# 898      156         4257  2010  1172.000      E    NaN  New Zealand
#
#                          variable_name
# 0        Agricultural water withdrawal
# 1          Industrial water withdrawal
# ...

# %%
mydata.head()
# Out:
#    area_id  variable_id  year    value symbol   md     area  \
# 0        4         4250  2012    4.990      I  [1]  Algeria
# 1        4         4252  2012    0.415      I  [2]  Algeria
# 2        4         4251  2012    3.020      I  [3]  Algeria
# 3        4         4253  2012    8.425      I  NaN  Algeria
# 4        4         4257  2012  225.000      K  NaN  Algeria
#
#                        variable_name
# 0      Agricultural water withdrawal
# 1        Industrial water withdrawal
# 2         Municipal water withdrawal
# 3             Total water withdrawal
# 4  Total water withdrawal per capita

# %%
mydata.tail()
# Out:
#      area_id  variable_id  year     value symbol     md         area  \
# 894      156         4250  2010     3.207      E  [126]  New Zealand
# 895      156         4252  2010     1.184      E    NaN  New Zealand
# 896      156         4251  2010     0.810      E  [127]  New Zealand
# 897      156         4253  2010     5.201      E    NaN  New Zealand
# 898      156         4257  2010  1172.000      E    NaN  New Zealand
#
#                          variable_name
# 894      Agricultural water withdrawal
# 895        Industrial water withdrawal
# 896         Municipal water withdrawal
# 897             Total water withdrawal
# 898  Total water withdrawal per capita

# %%
mydata.columns
# Out:
# Index(['area_id', 'variable_id', 'year', 'value', 'symbol', 'md', 'area',
#        'variable_name'],
#       dtype='object')

# %%
mydata.columns = [['Area_id', 'Variable_id', 'Year', 'Value', 'Symbol', 'Md', 'Area',
       'Variable_name']]

# %%
len(mydata.columns)
# Out:
# 8

# %%
len(mydata)
# Out:
# 899

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899 entries, 0 to 898
# Data columns (total 8 columns):
# (Area_id,)          899 non-null int64
# (Variable_id,)      899 non-null int64
# (Year,)             899 non-null int64
# (Value,)            899 non-null float64
# (Symbol,)           578 non-null object
# (Md,)               113 non-null object
# (Area,)             899 non-null object
# (Variable_name,)    899 non-null object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 56.3+ KB

# %%
mydata.describe()
# Out:
#           Area_id  Variable_id         Year        Value
# count  899.000000   899.000000   899.000000   899.000000
# mean   130.487208  4252.609566  2007.142380   106.689934
# std     76.219080     2.422049     4.838802   333.192434
# min      1.000000  4250.000000  1975.000000     0.000000
# 25%     64.500000  4251.000000  2005.000000     0.149950
# 50%    129.000000  4252.000000  2007.000000     1.267000
# 75%    194.000000  4253.000000  2011.000000    28.575000
# max    351.000000  4257.000000  2016.000000  5753.000000

# %%
mydata[2:8]
# Out:
#    area_id  variable_id  year     value symbol   md     area  \
# 2        4         4251  2012    3.0200      I  [3]  Algeria
# 3        4         4253  2012    8.4250      I  NaN  Algeria
# 4        4         4257  2012  225.0000      K  NaN  Algeria
# 5        7         4250  2005    0.1467      L  [4]   Angola
# 6        7         4252  2005    0.2396      L  NaN   Angola
# 7        7         4251  2005    0.3195      L  NaN   Angola
#
#                        variable_name
# 2         Municipal water withdrawal
# 3             Total water withdrawal
# 4  Total water withdrawal per capita
# 5      Agricultural water withdrawal
# 6        Industrial water withdrawal
# 7         Municipal water withdrawal

# %%
mydata[['year','md']]
# Out:
#      year     md
# 0    2012    [1]
# 1    2012    [2]
# 2    2012    [3]
# 3    2012    NaN
# 4    2012    NaN
# ..    ...    ...
# 894  2010  [126]
# 895  2010    NaN
# 896  2010  [127]
# 897  2010    NaN
# 898  2010    NaN
#
# [899 rows x 2 columns]

# %%
mydata[2:7][['Year','Md']]
# Out:
#    Year   Md
# 2  2012  [3]
# 3  2012  NaN
# 4  2012  NaN
# 5  2005  [4]
# 6  2005  NaN

# %%
mydata[2::175]
# Out:
#     Area_id Variable_id  Year     Value Symbol    Md                    Area  \
# 2         4        4251  2012    3.0200      I   [3]                 Algeria
# 177     147        4251  2000    0.0730    NaN  [29]                 Namibia
# 352      89        4257  2006  240.9000      K   NaN               Guatemala
# 527     112        4250  2015    0.5750    NaN  [79]                  Jordan
# 702      80        4252  2008    0.0488      E   NaN  Bosnia and Herzegovina
# 877     230        4253  2010   14.8500    NaN   NaN                 Ukraine
#
#                          Variable_name
# 2           Municipal water withdrawal
# 177         Municipal water withdrawal
# 352  Total water withdrawal per capita
# 527      Agricultural water withdrawal
# 702        Industrial water withdrawal
# 877             Total water withdrawal

# %%
mydata['year']
# Out:
# 0      2012
# 1      2012
# 2      2012
# 3      2012
# 4      2012
#        ...
# 894    2010
# 895    2010
# 896    2010
# 897    2010
# 898    2010
# Name: year, Length: 899, dtype: int64

# %%
mydata['Col']=mydata['year']*mydata['area_id']

# %%
mydata
# Out:
#      area_id  variable_id  year     value symbol     md         area  \
# 0          4         4250  2012     4.990      I    [1]      Algeria
# 1          4         4252  2012     0.415      I    [2]      Algeria
# 2          4         4251  2012     3.020      I    [3]      Algeria
# 3          4         4253  2012     8.425      I    NaN      Algeria
# 4          4         4257  2012   225.000      K    NaN      Algeria
# ..       ...          ...   ...       ...    ...    ...          ...
# 894      156         4250  2010     3.207      E  [126]  New Zealand
# 895      156         4252  2010     1.184      E    NaN  New Zealand
# 896      156         4251  2010     0.810      E  [127]  New Zealand
# 897      156         4253  2010     5.201      E    NaN  New Zealand
# 898      156         4257  2010  1172.000      E    NaN  New Zealand
#
#                          variable_name     Col
# 0        Agricultural water withdrawal    8048
# ...

# %%
mydata.drop('Col', axis=1)
# Out:
#      area_id  variable_id  year     value symbol     md         area  \
# 0          4         4250  2012     4.990      I    [1]      Algeria
# 1          4         4252  2012     0.415      I    [2]      Algeria
# 2          4         4251  2012     3.020      I    [3]      Algeria
# 3          4         4253  2012     8.425      I    NaN      Algeria
# 4          4         4257  2012   225.000      K    NaN      Algeria
# ..       ...          ...   ...       ...    ...    ...          ...
# 894      156         4250  2010     3.207      E  [126]  New Zealand
# 895      156         4252  2010     1.184      E    NaN  New Zealand
# 896      156         4251  2010     0.810      E  [127]  New Zealand
# 897      156         4253  2010     5.201      E    NaN  New Zealand
# 898      156         4257  2010  1172.000      E    NaN  New Zealand
#
#                          variable_name
# 0        Agricultural water withdrawal
# 1          Industrial water withdrawal
# ...

# %%
mydata=mydata.drop('Col', axis=1)

# %%
mydata
# Out:
#      area_id  variable_id  year     value symbol     md         area  \
# 0          4         4250  2012     4.990      I    [1]      Algeria
# 1          4         4252  2012     0.415      I    [2]      Algeria
# 2          4         4251  2012     3.020      I    [3]      Algeria
# 3          4         4253  2012     8.425      I    NaN      Algeria
# 4          4         4257  2012   225.000      K    NaN      Algeria
# ..       ...          ...   ...       ...    ...    ...          ...
# 894      156         4250  2010     3.207      E  [126]  New Zealand
# 895      156         4252  2010     1.184      E    NaN  New Zealand
# 896      156         4251  2010     0.810      E  [127]  New Zealand
# 897      156         4253  2010     5.201      E    NaN  New Zealand
# 898      156         4257  2010  1172.000      E    NaN  New Zealand
#
#                          variable_name
# 0        Agricultural water withdrawal
# 1          Industrial water withdrawal
# ...

# %%
mydata.value
# Out:
# 0         4.990
# 1         0.415
# 2         3.020
# 3         8.425
# 4       225.000
#          ...
# 894       3.207
# 895       1.184
# 896       0.810
# 897       5.201
# 898    1172.000
# Name: value, Length: 899, dtype: float64

# %%
mydata.value >2
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 894     True
# 895    False
# 896    False
# 897     True
# 898     True
# Name: value, Length: 899, dtype: bool

# %%
mydata[mydata.value > 2]
# Out:
#      area_id  variable_id  year     value symbol     md         area  \
# 0          4         4250  2012     4.990      I    [1]      Algeria
# 2          4         4251  2012     3.020      I    [3]      Algeria
# 3          4         4253  2012     8.425      I    NaN      Algeria
# 4          4         4257  2012   225.000      K    NaN      Algeria
# 9          7         4257  2005    36.790      K    NaN       Angola
# ..       ...          ...   ...       ...    ...    ...          ...
# 888       10         4257  2015   724.700      K    NaN    Australia
# 893       66         4257  2005   101.700      K    NaN         Fiji
# 894      156         4250  2010     3.207      E  [126]  New Zealand
# 897      156         4253  2010     5.201      E    NaN  New Zealand
# 898      156         4257  2010  1172.000      E    NaN  New Zealand
#
#                          variable_name
# 0        Agricultural water withdrawal
# 2           Municipal water withdrawal
# ...

# %%
mydata[mydata.area_id >50 and mydata.value >3] # and in pyth. considers only 1 bool value on either side i.e. single true/false
# on left and right, here we are getting a series of true/false values on both side :. use &
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-2dc04e7fe940> in <module>
# ----> 1 mydata[mydata.area_id > 50 and mydata.value > 3]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
mydata[mydata.area_id  > 50 & mydata.value > 3] # use parenthases for order of predesense
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1253         try:
# -> 1254             result = op(x, y)
#    1255         except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\roperator.py in rand_(left, right)
#      52 def rand_(left, right):
# ---> 53     return operator.and_(right, left)
#      54
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1268                 try:
# ...

# %%
mydata[(mydata.area_id  > 50) & (mydata.value > 3)]
# Out:
#      area_id  variable_id  year     value symbol     md  \
# 14        53         4257  2001    17.530      K    NaN
# 24       233         4257  2005    57.350      K    NaN
# 64       107         4257  2005    82.120      K    NaN
# 69       250         4257  2005    11.420      K    NaN
# 74        72         4257  2000    25.490      K    NaN
# ..       ...          ...   ...       ...    ...    ...
# 883      229         4257  2012   129.200      E    NaN
# 893       66         4257  2005   101.700      K    NaN
# 894      156         4250  2010     3.207      E  [126]
# 897      156         4253  2010     5.201      E    NaN
# 898      156         4257  2010  1172.000      E    NaN
#
#                                  area                      variable_name
# 14                              Benin  Total water withdrawal per capita
# 24                       Burkina Faso  Total water withdrawal per capita
# ...

# %%
mydata[mydata.area == 'Fiji']
# Out:
#      area_id  variable_id  year     value symbol   md  area  \
# 889       66         4250  2005    0.0500      I  NaN  Fiji
# 890       66         4252  2005    0.0096      I  NaN  Fiji
# 891       66         4251  2005    0.0253      I  NaN  Fiji
# 892       66         4253  2005    0.0849      I  NaN  Fiji
# 893       66         4257  2005  101.7000      K  NaN  Fiji
#
#                          variable_name
# 889      Agricultural water withdrawal
# 890        Industrial water withdrawal
# 891         Municipal water withdrawal
# 892             Total water withdrawal
# 893  Total water withdrawal per capita

# %%
mydata[mydata.area != 'Fiji']
# Out:
#      area_id  variable_id  year     value symbol     md         area  \
# 0          4         4250  2012     4.990      I    [1]      Algeria
# 1          4         4252  2012     0.415      I    [2]      Algeria
# 2          4         4251  2012     3.020      I    [3]      Algeria
# 3          4         4253  2012     8.425      I    NaN      Algeria
# 4          4         4257  2012   225.000      K    NaN      Algeria
# ..       ...          ...   ...       ...    ...    ...          ...
# 894      156         4250  2010     3.207      E  [126]  New Zealand
# 895      156         4252  2010     1.184      E    NaN  New Zealand
# 896      156         4251  2010     0.810      E  [127]  New Zealand
# 897      156         4253  2010     5.201      E    NaN  New Zealand
# 898      156         4257  2010  1172.000      E    NaN  New Zealand
#
#                          variable_name
# 0        Agricultural water withdrawal
# 1          Industrial water withdrawal
# ...

# %%
mydata.variable_name.unique()
# Out:
# array(['Agricultural water withdrawal', 'Industrial water withdrawal',
#        'Municipal water withdrawal', 'Total water withdrawal',
#        'Total water withdrawal per capita'], dtype=object)

# %%
mydata.at[5,'value']
# Out:
# 0.1467

# %%
mydata.iat[5,3]
# Out:
# 0.1467

# %%
s= mydata[::25]
s
# Out:
#      area_id  variable_id  year     value symbol    md  \
# 0          4         4250  2012    4.9900      I   [1]
# 25        29         4250  2000    0.2220      I   NaN
# 50        45         4250  1999    0.0047    NaN   NaN
# 75        59         4250  2010   67.0000    NaN   NaN
# 100       75         4250  1999    0.0392      L  [18]
# 125      122         4250  1999    0.0038      L  [22]
# 150      133         4250  2006    5.0750    NaN   NaN
# 175      147         4250  2002    0.2010    NaN   NaN
# 200      195         4253  2002    2.2210      I   NaN
# 225      277         4253  2011    0.6580    NaN   NaN
# 250      226         4253  2008    0.6370    NaN   NaN
# 275        9         4253  2011   37.7800    NaN   NaN
# 300       33         4251  2007    5.8780      E   NaN
# 325       55         4251  2010    0.0190      I   NaN
# 350       89         4251  2006    0.8350    NaN   NaN
# 375      138         4251  2015   12.4800    NaN   NaN
# ...

# %%
s.at[25,'value'] # see's where label 25 is and passes value for that cell there it's second row
# Out:
# 0.222

# %%
s.iat[25,3] # 25 here means value at 26th index location that is 26th row
# Out:
# 0.19

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
plt.rcParams['figure.figsize']=9,9
warnings.filterwarnings('ignore')

# %%
kt = sns.distplot(s['value'])
kt

# %%
sns.boxplot(data=s, x='year',y='value')

# %%
sns.lmplot('year','value',s)

# %%
sns.lmplot('year','value',s, fit_reg=False)

# %%
sns.lmplot('year','value',s, fit_reg=False, hue= 'variable_name', size=7) # rcParams does'nt work for lmplot

# %%
sns.lmplot(x='year', y='value',data=s, hue='variable_name',size=7,scatter_kws={'s': 150}, fit_reg=False) # scatter_kws for 
# size of marker

# %%
sns.lmplot(x='value',y='year',data=s, hue='variable_name', size=7,scatter_kws={'s':200},fit_reg=False)
